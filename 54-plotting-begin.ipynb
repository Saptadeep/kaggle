# %%
import matplotlib.pyplot as plt

plt.axis([-6,6,-8,-8])
plt.plot(2,3, 'ro')
plt.show()
# Out:
# /tmp/ipykernel_20/19584884.py:3: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.axis([-6,6,-8,-8])
